# %%
import pandas as pd

# %%
pd.read_json('./final_datasets/export_commodities_by_air.json')
# Out:
#                  Essential oils and resinoids,perfumery  \
# Austria                                               0
# China                                                38
# Finland                                               0
# France                                                0
# Germany                                               0
# Hong Kong                                             0
# Hungary                                               0
# Indonesia                                             0
# Italy                                                 0
# Japan                                                 0
# South Korea                                          16
# Netherlands                                           0
# Other Countries                                      80
# Portugal                                              0
# Singapore                                             0
# Spain                                                 0
# ...

# %%
pd.read_json('./final_datasets/export_commodities_by_sea.json')
# Out:
#                       Cotton  \
# Algeria                    0
# Argentina                  0
# Australia                  0
# Austria                    0
# Bahrain                   26
# Belgium                    0
# Brazil                    14
# Canada                     0
# China                    121
# Colombia                  13
# Czech Republic             0
# Denmark                    0
# Egypt                     14
# Finland                    0
# France                     0
# Germany                   14
# Greece                     0
# Hong Kong                 25
# Indonesia                 18
# Iran                       0
# Italy                     24
# Japan                     42
# Kenya                      0
# South Korea              230
# Kuwait                     0
# Malaysia                  44
# Mexico                     0
# Netherlands                0
# Nigeria                    0
# Norway                     0
# Other Countries          406
# ...

# %%
pd.read_json('./final_datasets/import_commodities_by_sea.json')
# Out:
#                       Animal or Vegetable fats and Oil products  \
# Algeria                                                       0
# Argentina                                                   240
# Australia                                                     0
# Austria                                                       0
# Belgium                                                       0
# Belgium                                                       0
# Canada                                                        0
# China                                                         0
# Egypt                                                         0
# Finland                                                       0
# France                                                        0
# Germany                                                       0
# Hong Kong                                                     0
# Indonesia                                                  1137
# ...

# %%
pd.read_json('./final_datasets/import_commodities_by_air.json')
# Out:
#                       Electrical Machinery,.Equipment,and parts there of sound recorders and reproduces TV image  \
# Australia                                                             0
# Austria                                                               0
# Belgium                                                              15
# Canada                                                               23
# China                                                              3201
# Denmark                                                              44
# Egypt                                                                 0
# Finland                                                             572
# France                                                              141
# Germany                                                             288
# Hong Kong                                                           811
# ...

# %%
pd.read_json('./datasets/import_and_export_by_cities.json')
# Out:
#             Item  By Sea Chennai (Value Rs. in Crores)  \
# 1  Total Exports                                 42570
#
#   By Sea Cuddalore (Value Rs. in Crores)   \
# 1                                      NA
#
#    By Sea Thoothukudi  (Value Rs. in Crores)   \
# 1                                       39995
#
#    By Sea Nagapattinam (Value Rs. in Crores)   \
# 1                                         342
#
#    By Sea Py- 03 Port (Value Rs. in Crores)   \
# 1                                        516
#
#   By Sea Thirukadiyur (Value Rs. in Crores)   \
# 1                                         NA
#
#    By Sea Ennore Port (Value Rs. in Crores)   \
# 1                                        700
#
#   By Sea Ennore Minor (Value Rs. in Crores)   \
# 1                                         NA
#
#   By Sea Kudankulam (Value Rs. in Crores)   \
# 1                                       NA
#
#    Total By Sea (Value Rs. in Crores)  By Air Chennai (Value Rs. in Crores)   \
# ...

# %%
pd.read_json('./datasets/imports_of_commodites_of_cities.json')
# Out:
#                                          Commodity Group  \
# 1                                 Chennai Port : Cereals
# 2      Chennai Port : Dairy produce eggs,honey and ed...
# 3      Chennai Port : Edible fruits and nuts,peel or ...
# 4              Chennai Port : Coffee,tea,mate and spices
# 5           Chennai Port : Sugar and sugar confectionery
# 6      Chennai Port : Oil seeds,oleaginous fruits,gra...
# 7      Chennai Port : Edible vegetables and certain r...
# 8       Chennai Port : Miscellaneous edible preparations
# 9      Chennai Port : Salt,Sulpher,earths and stone p...
# 10     Chennai Port : Ores,slag and ash,mineral fuels...
# 11     Chennai Port : In- organic chemicals,organic o...
# 12                      Chennai Port : Organic chemicals
# 13                Chennai Port : Pharmaceutical products
# 14                            Chennai Port : Fertilisers
# 15     Chennai Port : Tanning or dyeing extract dyes,...
# ...

# %%
pd.read_json('./datasets/net_import_and_exports_for_tamil_nadu.json')
# Out:
#       Description  Value of Foreign Trade Tamil Nadu (Rs.in Crores)  \
# 1  Exports By Sea                                             84123
# 2  Exports By Air                                              7639
# 3   Total Exports                                             91762
# 4  Imports By Sea                                            154429
# 5  Imports By Air                                             35732
# 6   Total Imports                                            190161
#
#   Value of Foreign Trade All India* (Rs.in Crores)  \
# 1                                               NA
# 2                                               NA
# 3                                           655864
# 4                                               NA
# 5                                               NA
# 6                                          1012312
#
#   Percentage share of Foreign Trade through Tamil Nadu Ports to All India
# ...

# %%
pd.read_json('./datasets/yearwise_import_export.json')
# Out:
#       Years  Exports Value (Rs. in Crores)  Imports Value  (Rs. in Crores)
# 1   1991-92                        5389.88                         5359.21
# 2   1992-93                        6884.23                         7310.65
# 3   1993-94                        9085.80                         8111.80
# 4   1994-95                       12460.09                        12541.53
# 5   1995-96                       15832.83                        17416.72
# 6   1996-97                       17596.27                        14966.54
# 7   1997-98                       16529.64                        36877.89
# 8   1998-99                       18771.28                        23482.90
# 9   1999-00                       26983.75                        25600.16
# 10  2000-01                       11736.96                        18821.37
# 11  2001-02                       12631.24                        18628.05
# ...
