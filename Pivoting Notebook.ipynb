# %%
import pandas as pd
import numpy as np
import sklearn
import json

# %%
commodities = pd.read_json('./datasets/import_commodities_by_air.json')

# %%
commodities
# Out:
#      S.No                                    Commodity Group  \
# 0       1  Natural or Cultural pearl precious or semi pre...
# 1       2  Natural or Cultural pearl precious or semi pre...
# 2       3  Natural or Cultural pearl precious or semi pre...
# 3       4  Natural or Cultural pearl precious or semi pre...
# 4       5  Natural or Cultural pearl precious or semi pre...
# ..    ...                                                ...
# 73     69                        Raw hides,skins and leather
# 74     70                        Raw hides,skins and leather
# 75     71                        Raw hides,skins and leather
# 76     72                        Raw hides,skins and leather
# 77  Total                  Total Raw hides,skins and leather
#
#    Name of the Country  Value (Rs in Cr.)
# 0          Switzerland               4390
# 1            Australia               2251
# 2        South Africa                1105
# 3                  UAE               1086
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(commodities)
# Out:
#      S.No                                    Commodity Group  \
# 0       1  Natural or Cultural pearl precious or semi pre...
# 1       2  Natural or Cultural pearl precious or semi pre...
# 2       3  Natural or Cultural pearl precious or semi pre...
# 3       4  Natural or Cultural pearl precious or semi pre...
# 4       5  Natural or Cultural pearl precious or semi pre...
# 5       6  Natural or Cultural pearl precious or semi pre...
# 6       7  Natural or Cultural pearl precious or semi pre...
# 7       8  Natural or Cultural pearl precious or semi pre...
# 8       9  Natural or Cultural pearl precious or semi pre...
# 9      10  Natural or Cultural pearl precious or semi pre...
# 10     11  Natural or Cultural pearl precious or semi pre...
# 11     12  Natural or Cultural pearl precious or semi pre...
# 12     13  Natural or Cultural pearl precious or semi pre...
# 13     14  Natural or Cultural pearl precious or semi pre...
# ...

# %%
commodities = commodities[commodities['S.No'] != 'Total']

# %%
commodities = commodities[commodities['Commodity Group'] != False]

# %%
commodities
# Out:
#    S.No                                    Commodity Group  \
# 0     1  Natural or Cultural pearl precious or semi pre...
# 1     2  Natural or Cultural pearl precious or semi pre...
# 2     3  Natural or Cultural pearl precious or semi pre...
# 3     4  Natural or Cultural pearl precious or semi pre...
# 4     5  Natural or Cultural pearl precious or semi pre...
# ..  ...                                                ...
# 72   68                        Raw hides,skins and leather
# 73   69                        Raw hides,skins and leather
# 74   70                        Raw hides,skins and leather
# 75   71                        Raw hides,skins and leather
# 76   72                        Raw hides,skins and leather
#
#    Name of the Country  Value (Rs in Cr.)
# 0          Switzerland               4390
# 1            Australia               2251
# 2        South Africa                1105
# 3                  UAE               1086
# ...

# %%
pivot_table = commodities.pivot(index='Name of the Country', columns='Commodity Group', values='Value (Rs in Cr.)')

# %%
pivot_table.fillna(0, inplace=True)

# %% [markdown]
# usa, korea, usa, other countries, hongkong

# %%
pivot_table
# Out:
# Commodity Group      Electrical Machinery,.Equipment,and parts there of sound recorders and reproduces TV image  \
# Name of the Country
# Australia                                                          0.0
# Austria                                                            0.0
# Belgium                                                           15.0
# Canada                                                            23.0
# China                                                           3201.0
# Denmark                                                           44.0
# Egypt                                                              0.0
# Finland                                                          572.0
# France                                                           141.0
# Germany                                                          288.0
# Hong Kong                                                        811.0
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(pivot_table)
# Out:
# Commodity Group      Electrical Machinery,.Equipment,and parts there of sound recorders and reproduces TV image  \
# Name of the Country
# Australia                                                          0.0
# Austria                                                            0.0
# Belgium                                                           15.0
# Canada                                                            23.0
# China                                                           3201.0
# Denmark                                                           44.0
# Egypt                                                              0.0
# Finland                                                          572.0
# France                                                           141.0
# Germany                                                          288.0
# Hong Kong                                                        811.0
# ...
